# %%
import sympy as sym
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from sympy import var
from sympy.plotting import plot3d

sym.init_printing()

var('theta phi')
# z = sym.Symbol('z')
# r = sym.Symbol('r')
# theta = sym.Symbol('theta')
# phi = sym.Symbol('phi')
# a = sym.Symbol('a')
pi = sym.pi


# Associated Legendre polynomials
def P(l, m):
    f = (z**2 - 1) ** l
    
    for i in range(l+m):
        f = sym.diff(f)
    
    return (1-z**2)**sym.Rational(m/2) * f / (2**l * sym.factorial(l))


# Spherical harmonics
def Y(l, m):
    return sym.exp(1j*m*phi) * P(l, m).subs([(z, sym.cos(theta))]) \
                * (-1)**abs(m) * sym.sqrt((2*l+1)/(4*pi) * (sym.factorial(l-m))/(sym.factorial(l+m)))

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from sympy import var
from sympy.plotting import plot3d

fig = plt.figure()  # プロット領域の作成
ax = fig.gca(projection = '3d')

# figure サイズを8*8に
plt.rcParams['figure.figsize'] = 8, 8



for l in range(3):
    for m in range(l):
        r = (Y(l, m))**2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-403cca590d63> in <module>()
#      17 for l in range(3):
#      18     for m in range(l):
# ---> 19         r = (Y(l, m))**2
#      20
#      21
#
# <ipython-input-122-fa8efc0617ea> in Y(l, m)
#      28 # Spherical harmonics
#      29 def Y(l, m):
# ---> 30     return sym.exp(1j*m*phi) * P(l, m).subs([(z, sym.cos(theta))])                 * (-1)**abs(m) * sym.sqrt((2*l+1)/(4*pi) * (sym.factorial(l-m))/(sym.factorial(l+m)))
#      31
#
# AttributeError: 'numpy.ndarray' object has no attribute 'subs'
