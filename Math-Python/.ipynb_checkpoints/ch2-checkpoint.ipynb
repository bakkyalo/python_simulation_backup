# %%
simplelist = [1, 2, 3]

simplelist[0]
# Out:
# 1

# %%
stringlist = ['a string', 'b string', 'c string']

stringlist[0]
# Out:
# 'a string'

# %%
emptylist = []

emptylist
# Out:
# []

# %%
emptylist.append(1)

emptylist
# Out:
# [1]

# %%
simpletuple = (1, 2, 3)
simpletuple[0]
# Out:
# 1

# %%
# リストに対するforループ
l = [1, 2, 3]
for item in l:
    print(item)
# Out:
# 1
# 2
# 3

# %%
# enumerate() はindex番号と値をこの順で出力する
l = ['あんぱんまん', 'しょくぱんまん', 'カレーパンマン']
for index, item in enumerate(l):
    print(index, item)
# Out:
# 0 あんぱんまん
# 1 しょくぱんまん
# 2 カレーパンマン

# %%
# パッケージ = モジュールの集まり

x_number = [1, 2, 3]
y_number = [2, 4, 6]

from pylab import plot, show
plot(x_number, y_number)
show()

# %%
from pylab import plot, show
# プロットした点に印をつける
x_number = [1, 2, 3]
y_number = [2, 4, 6]

from pylab import plot, show
plot(x_number, y_number, marker = 'o')    # 'o', '*', 'x', '+' 
show()

# %%
from pylab import plot, show
# プロットした点だけ
x_number = [1, 2, 3]
y_number = [2, 4, 6]

from pylab import plot, show
plot(x_number, y_number, 'o')    # 'o', '*', 'x', '+' , marker=を書かない
show()

# %%
from pylab import plot, show

years = range(2000, 2013)
nyc_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]
plot(years, nyc_temp, marker = 'o')
show()

# %%
from pylab import plot, show

nyc_temp_2000 = [31.3, 37.3, 47.2, 51.0, 63.5, 71.3, 72.3, 72.7, 66.0,
57.0, 45.3, 31.1]
nyc_temp_2006 = [40.9, 35.7, 43.1, 55.7, 63.1, 71.0, 77.9, 75.8, 66.6,
56.2, 51.9, 43.6]
nyc_temp_2012 = [37.3, 40.9, 50.9, 54.8, 65.1, 71.0, 78.8, 76.7, 68.8,
58.0, 43.9, 41.5]

months = range(1, 13)

plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)
show()

# %%
from pylab import plot, show

# 3つに分けてもよい
plot(months, nyc_temp_2000)
plot(months, nyc_temp_2006)
plot(months, nyc_temp_2012)
show()

# %%
# 凡例をつける
from pylab import plot, show
from pylab import legend

# 3つに分けてもよい
plot(months, nyc_temp_2000)
plot(months, nyc_temp_2006)
plot(months, nyc_temp_2012)
legend([2000, 2006, 2012], loc = 'upper right')
show()

# %%
from pylab import plot, show, title, xlabel, ylabel, legend

plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)
title('Average monthly temperature in NYC')
xlabel('Month')
ylabel('Temperature')
legend([2000, 2006, 2012])
show()

# %%
from pylab import plot, show, axis

nyc_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]
plot(years, nyc_temp, marker = 'o')
axis(ymin=0)
# axis([0, 10, 0, 20])

show()

# %%
'''
Simple plot using pyplot
'''

import matplotlib.pyplot

def create_graph():
    x_numbers = [1, 2, 3]
    y_numbers = [2, 4, 6]
    matplotlib.pyplot.plot(x_numbers, y_numbers)
    matplotlib.pyplot.show()

if __name__ == '__main__':
    create_graph()

# %%
'''
Simple plot using pyplot
'''

import matplotlib.pyplot as plt

def create_graph():
    x_numbers = [1, 2, 3]
    y_numbers = [2, 4, 6]
    plt.plot(x_numbers, y_numbers)
    plt.show()

if __name__ == '__main__':
    create_graph()

# %%
'''
The relationship between gravitational force and
distance between two bodies
'''

import matplotlib.pyplot as plt
# draw a graph
def draw_graph(x, y):
    plt.plot(x, y, marker = 'o')
    plt.xlabel('Distance in meters')
    plt.ylabel('Gravitational force in newtons')
    plt.title('Gravitational force and distance')
    plt.show()
    
def generate_F_r():
    # generate values of x
    r = range(100, 1001, 50)
    # empty list to store the calculated values of F
    F = []
    # constant, G
    G = 6.674 * (10**-11)
    # two masses
    m1 = 0.5
    m2 = 1.5
    # calculate Force and add it to the list, F
    for dist in r:
        force = G*(m1*m2)/(dist**2)
        F.append(force)
    # call the draw_graph function
    draw_graph(r, F)

if __name__ == '__main__':
    generate_F_r()

# %%
'''
Draw the trajectory of a body in projectile motion
'''
from matplotlib import pyplot as plt
import math
def draw_graph(x, y):
    plt.plot(x, y)
    plt.xlabel('x-coordinate')
    plt.ylabel('y-coordinate')
    plt.title('Projectile motion of a ball')

'''
Generate equally spaced floating point numbers
between two given values
'''
def frange(start, final, interval):
    numbers = []
    while start < final:
        numbers.append(start)
        start = start + interval
    return numbers

def draw_trajectory(u, theta):
    theta = math.radians(theta)
    g = 9.8
    # Time of flight
    t_flight = 2*u*math.sin(theta)/g
    # find time intervals
    intervals = frange(0, t_flight, 0.001)
    # list of x and y coordinates
    x = []
    y = []
    for t in intervals:
        x.append(u*math.cos(theta)*t)
        y.append(u*math.sin(theta)*t - 0.5*g*t*t)
    draw_graph(x, y)
    
if __name__ == '__main__':
    try:
        u = float(input('Enter the initial velocity (m/s): '))
        theta = float(input('Enter the angle of projection (degrees): '))
    except ValueError:
        print('You enterd an invalid input')
        
    else:
        draw_trajectory(u, theta)
        plt.show()
# Out:
# Enter the initial velocity (m/s): 15
# Enter the angle of projection (degrees): 45

# %%
if __name__ == '__main__':
    u_list = [20, 40, 60]
    theta = 45
    for u in u_list:
        draw_trajectory(u, theta)
        
    # add a a legend and show the graph
    plt.legend(['20', '40', '60'])
    plt.show()

# %%
'''
Quadratic function calculator
'''
# assume values of x
x_values = range(-5, 10, 1)
y_values=[]

for x in x_values:
    # calculate the value of the quadratic function
    y = x**2 + 2*x + 1
    y_values.append(x**2 + 2*x + 1)
    print('x={0} y={1}'.format(x, y))
    
import matplotlib.pyplot as plt

plt.plot(x_values, y_values)
plt.xlabel('x-coordinate')
plt.ylabel('y-coordinate')
plt.title(r'y = x^2 + 2x + 1')
plt.show()
# Out:
# x=-5 y=16
# x=-4 y=9
# x=-3 y=4
# x=-2 y=1
# x=-1 y=0
# x=0 y=1
# x=1 y=4
# x=2 y=9
# x=3 y=16
# x=4 y=25
# x=5 y=36
# x=6 y=49
# x=7 y=64
# x=8 y=81
# x=9 y=100

# %%
n = int(input('How many trajectory? '))
for i in range(n):
    try:
        velocity = float(input('Enter the initial velocity for trajectory {0} (m/s): '.format(str(i+1))))
        angle = float(input('Enter the angle of projection for trajectory {0} (m/s): '.format(i+1)))
        draw_trajectory(velocity, angle)
    except ValueError:
        print('You entered an invalid input.')
        
    
plt.show()

# %%
n = int(input('How many trajectory? '))
for i in range(n):
    try:
        velocity = float(input('Enter the initial velocity for trajectory {0} (m/s): '.format(str(i+1))))
        angle = float(input('Enter the angle of projection for trajectory {0} (m/s): '.format(i+1)))
       
        draw_trajectory(velocity, angle)
    except ValueError:
        print('You entered an invalid input.')
        
plt.legend(range(1, n+1)) 
plt.show()
# Out:
# How many trajectory? 3
# Enter the initial velocity for trajectory 1 (m/s): 5
# Enter the angle of projection for trajectory 1 (m/s): 20
# Enter the initial velocity for trajectory 2 (m/s): 10
# Enter the angle of projection for trajectory 2 (m/s): 20
# Enter the initial velocity for trajectory 3 (m/s): 15
# Enter the angle of projection for trajectory 3 (m/s): 20

# %%
import numpy as np
plt.hist(np.random.randn(1000), color='blue', ec = 'black')
# Out:
# (array([ 13.,  58., 127., 263., 261., 156.,  85.,  29.,   7.,   1.]),
#  array([-2.76905136, -2.10868014, -1.44830892, -0.78793769, -0.12756647,
#          0.53280475,  1.19317597,  1.85354719,  2.51391842,  3.17428964,
#          3.83466086]),
#  <a list of 10 Patch objects>)

# %%
'''
Example of drawing a horizontal bar chart
'''
import matplotlib.pyplot as plt
def create_bar_chart(data,  labels):
    # number of bars
    num_bars = len(data)
    # This list is the point on the y-axis where each bar is centered. Here it will be [1, 2, 3, ...]
    positions = range(1, num_bars+1)
    plt.barh(positions, data, align='center')
    # set the label of each bar
    plt.yticks(positions, labels)
    plt.xlabel('Steps')
    plt.ylabel('Day')
    plt.title('Number of steps walked')
    # Turn on the grid which may assist in visual estimation
    plt.grid()
    plt.show()
    
if __name__ == '__main__':
    # Number of steps I walked during the past week
    steps = [6534, 7000, 8900, 10786, 3467, 11045, 5095]
    # Corresponding days
    labels = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
    create_bar_chart(steps, labels)

# %%
'''
支出を可視化する
'''

try:
    n = int(input('Enter the number of categories: '))
    for i in range(1, n):
        category = input('Enter Category: ')
        expenditure = input('Expenditure: ')
except ValueError:
    print('You entered an invalid input.')            

create_bar_chart(expenditure, category)
# Out:
# Enter the number of categories: 4
# Enter Category: 1
# Expenditure: 3
# Enter Category: 41
# Expenditure: 3
# Enter Category: 2
# Expenditure: 41

# %% [markdown]
# #####

# %%
'''
Question 2-4
'''

while True:
    try:
        n = int(input('Enter the number of categories: '))
    except(ValueError):
        print('You must enter integer!\n')
    else:
        print('Congratulations! You entered a valid number.')
        break
        
category = []
expenditure = []

try:
# Out:
# Enter the number of categories: 4
# Congratulations! You entered a valid number.
