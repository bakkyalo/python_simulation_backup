# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D

k1 = 1
k2 = 2
w = 2*np.pi/10

def wave(x, y, t):
    return np.sin(k1*x + k2*y - w*t)

def update(t, Z, line):
    Z = wave(X, Y, t)
    ax.clear()
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('wave')
    line = ax.plot_surface(X, Y, wave(X, Y, t))
    ax.set_zlim3d(bottom=-3, top=3)
    return line

fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('wave')

x = np.arange(-1.5*np.pi, 1.5*np.pi, 0.2)
y = np.arange(-1.5*np.pi, 1.5*np.pi, 0.2)
X, Y = np.meshgrid(x, y)
Z = wave(X, Y, 0)
line = ax.plot_surface(X, Y, Z)
ax.set_zlim3d(bottom=-3, top=3)

ani = animation.FuncAnimation(
    fig,
    update,
    fargs = (Z, line),
    interval = 100,
    frames = 20,
    repeat = False,
    blit = True
)

# ani.save('wave.gif', writer = 'imagemagick')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D

def data(i, z, line):
    z = np.sin(x+y+i)
    ax.clear()
    line = ax.plot_surface(x, y, z,color= 'b')
    return line,

n = 2.*np.pi
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(0,n,100)
y = np.linspace(0,n,100)
x,y = np.meshgrid(x,y)
z = np.sin(x+y)
line = ax.plot_surface(x, y, z,color= 'b')

ani = animation.FuncAnimation(fig, data, fargs=(z, line), interval=30, blit=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib nbagg
from math import sin, cos
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D

def wave(x, y, t):
    return np.sin(k1*x + k2*y - w*t)

def update(t, Z, line):
    Z = wave(X, Y, t)
    ax.clear()
    line = ax.plot_surface(X, Y, wave(X, Y, t), cmap = 'summer')
    ax.set_zlim3d(bottom=-3, top=3)
    return line

k1 = 1
k2 = 2
w = 0.2

fig = plt.figure()
ax = Axes3D(fig)
# ax = fig.add_subplot(111, projection='3d')
# ax.set_xlabel('x')
# ax.set_ylabel('y')
# ax.set_zlabel('wave')
#ax.set_zlabel('sin({0}x + {1}y - {2}t)'.format(k1, k2, w))

x = np.arange(-np.pi, np.pi, 0.2)
y = np.arange(-np.pi, np.pi, 0.2)
X, Y = np.meshgrid(x, y)
Z = wave(X, Y, 0)
line = ax.plot_surface(X, Y, Z, cmap='summer')
ax.set_zlim3d(bottom=-3, top=3)

ani = animation.FuncAnimation(
    fig,
    update,
    fargs = (Z, line),
    interval = 100,
    frames = 20,
    repeat = True,
    blit = True
)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\USER\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'
